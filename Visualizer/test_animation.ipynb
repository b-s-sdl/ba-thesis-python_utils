# %%
from matplotlib import rc_context
from matplotlib.animation import FuncAnimation

# %%
import yt

# %%
ts = yt.load("/ptmp/mpa/bseidl/Simulation-Runs/Data/23-05-15_NewMorphology_Test/id*/cloud.*.vtk")

# %%
plot = yt.SlicePlot(ts[0], "z", ("athena", "density"))
#plot.set_zlim(("gas", "density"), 8e-29, 3e-26)

fig = plot.plots[("athena", "density")].figure

# animate must accept an integer frame number. We use the frame number
# to identify which dataset in the time series we want to load
def animate(i):
    ds = ts[i]
    plot._switch_ds(ds)


animation = FuncAnimation(fig, animate, frames=len(ts))

# Override matplotlib's defaults to get a nicer looking font
with rc_context({"mathtext.fontset": "stix"}):
    animation.save("animation.mp4")
# Out:
# yt : [INFO     ] 2023-05-16 23:29:16,603 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2023-05-16 23:29:16,625 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2023-05-16 23:29:16,626 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2023-05-16 23:29:16,627 Assuming 1.0 = 1.0 g
# yt : [INFO     ] 2023-05-16 23:29:16,668 Parameters: current_time              = 0.0
# yt : [INFO     ] 2023-05-16 23:29:16,671 Parameters: domain_dimensions         = [228 230 230]
# yt : [INFO     ] 2023-05-16 23:29:16,672 Parameters: domain_left_edge          = [-25. -25. -25.]
# yt : [INFO     ] 2023-05-16 23:29:16,673 Parameters: domain_right_edge         = [25. 25. 25.]
# yt : [INFO     ] 2023-05-16 23:29:16,673 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-05-16 23:29:24,593 xlim = -25.000000 199.999957
# yt : [INFO     ] 2023-05-16 23:29:24,594 ylim = -25.000000 25.000000
# ...
