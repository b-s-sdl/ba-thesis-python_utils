# %%
import yt
from math import sqrt

# %%
def add_units(ds0, r_cloud, drat, T_cloud, M_wind):
    gamma = 5/3
    
    v_wind = M_wind * sqrt(drat) * sqrt(gamma*T_cloud)
    
    t_cc = sqrt(drat) * r_cloud / v_wind
    
    rho_cloud = drat
    
    p0 = T_cloud * rho_cloud
    
    print(gamma,v_wind,t_cc,rho_cloud,p0)
    
    ds0.define_unit("t_cc", (t_cc,"s"), tex_repr = r"t_{\rm cc}")
    ds0.define_unit("r_cl", (r_cloud, "cm"), tex_repr = r"r_{\rm cl}")
    ds0.define_unit("v_wind", (v_wind, "cm/s"), tex_repr = r"v_{\rm wind}")
    ds0.define_unit("rho_cl", (rho_cloud, "g/cm**3"), tex_repr = r"\rho_{\rm cl}")
    ds0.define_unit("p0", (p0, "dyn/cm**2"), tex_repr = r"p_{0}")
    ds0.define_unit("T_cl", (T_cloud, 'cm*dyne/g'), tex_repr = r"T_{\rm cl}")

# %%
ds = yt.load("/ptmp/mpa/bseidl/Simulation-Runs/2023-06-10_multiCloud_Series2-3_0dist/data/id0/cloud.0000.vtk")

#add_units(ds, 5, 100, 1, 1.5)
#
#print(ds.field_list)
#
#units_override = {
#    "length_unit": (1.0, "r_cl"),
#    "time_unit": (1.0, "t_cc")
#}
# Out:
# yt : [INFO     ] 2023-06-10 17:30:43,929 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2023-06-10 17:30:43,954 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2023-06-10 17:30:43,956 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2023-06-10 17:30:43,957 Assuming 1.0 = 1.0 g
# yt : [INFO     ] 2023-06-10 17:30:43,993 Parameters: current_time              = 0.0
# yt : [INFO     ] 2023-06-10 17:30:43,994 Parameters: domain_dimensions         = [160 114 160]
# yt : [INFO     ] 2023-06-10 17:30:43,996 Parameters: domain_left_edge          = [-50. -45. -50.]
# yt : [INFO     ] 2023-06-10 17:30:43,997 Parameters: domain_right_edge         = [50. 45. 50.]
# yt : [INFO     ] 2023-06-10 17:30:43,998 Parameters: cosmological_simulation   = 0

# %%
slc2 = yt.SlicePlot(ds, "z", ("gas","temperature"), buff_size = (1000,1000))
#slc3 = yt.SlicePlot(ds, "z", ("athena","density"))
#slc1 = yt.SlicePlot(ds, "z", ('athena', 'specific_scalar[0]'))
            
#slc3.save(mpl_kwargs=dict(dpi=300))


#slc3.set_unit(("athena","density"), "t_cc")

#slc3.annotate_timestamp(corner="upper_left")
#slc.save("test.png", mpl_kwargs=dict(dpi=300))
slc2.show()
#slc1.show()
#slc3.show()
# Out:
# yt : [INFO     ] 2023-06-10 17:31:01,120 xlim = -50.000000 375.000000
# yt : [INFO     ] 2023-06-10 17:31:01,121 ylim = -45.000000 45.000001
# yt : [INFO     ] 2023-06-10 17:31:01,123 xlim = -50.000000 375.000000
# yt : [INFO     ] 2023-06-10 17:31:01,124 ylim = -45.000000 45.000001
# yt : [INFO     ] 2023-06-10 17:31:01,125 Making a fixed resolution buffer of (('gas', 'temperature')) 1000 by 1000
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
